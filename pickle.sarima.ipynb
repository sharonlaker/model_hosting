# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
#define function for kpss test
from statsmodels.tsa.stattools import kpss
#define KPSS
def kpss_test(timeseries):
    print ('Results of KPSS Test:')
    kpsstest = kpss(timeseries, regression='c')
    kpss_output = pd.Series(kpsstest[0:3], index=['Test Statistic','p-value','Lags Used'])
    for key,value in kpsstest[3].items():
      kpss_output['Critical Value (%s)'%key] = value
    print (kpss_output)

# %%
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
data = pd.read_csv('fake3-1.csv')

# %%
df = data.filter(['Timestamp','Water'], axis=1)

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.isna().sum()

df = df.dropna()
df.isnull().sum()

df = df.set_index('Timestamp')

# %%
df.count()
# Out:
# Water    5501
# dtype: int64

# %%
# df1.drop(df1.index[200:5501],0,inplace=True)

# %%
df.count()
# Out:
# Water    5501
# dtype: int64

# %%
df1 = df['Water'].resample('MS').mean()
df1.plot(figsize = (15, 6))
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(df1, model='additive')
fig = decomposition.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    df1test = adfuller(timeseries, autolag='AIC')
    df1output = pd.Series(df1test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in df1test[4].items():
       df1output['Critical Value (%s)'%key] = value
    print (df1output)

print(adf_test(df1))
print(kpss_test(df1))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.437729e+00
# p-value                        1.797666e-13
# #Lags Used                     1.000000e+00
# Number of Observations Used    1.800000e+02
# Critical Value (1%)           -3.467211e+00
# Critical Value (5%)           -2.877735e+00
# Critical Value (10%)          -2.575403e+00
# dtype: float64
# None
# Results of KPSS Test:
# Test Statistic           0.277254
# p-value                  0.100000
# Lags Used                2.000000
# Critical Value (10%)     0.347000
# Critical Value (5%)      0.463000
# Critical Value (2.5%)    0.574000
# Critical Value (1%)      0.739000
# dtype: float64
# None
# /home/sharon/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
# df2 = df1 - df1.shift(1)
# df2 = df2.dropna()

# df2.plot()
# plt.show()

# # print(adf_test(df1))

# %%
# df3 = df2 - df2.shift(12)
# df3 =df2.dropna()

# df3.plot()
# plt.show()

# %%
test_result=adfuller(df1)

# %%
def adfuller_test(df1):
    result=adfuller(df1)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df1)
# Out:
# ADF Test Statistic : -8.437728514115904
# p-value : 1.7976659118797226e-13
# #Lags Used : 1
# Number of Observations Used : 180
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(df1)
matplotlib.pyplot.show()
plot_pacf(df1)
matplotlib.pyplot.show()

# %%
p = range(0, 3)
d = range(1,2)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
seasonal_pdq
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 1, 1) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 1) x (0, 1, 2, 12)
# SARIMAX: (0, 1, 2) x (1, 1, 0, 12)
# SARIMAX: (0, 1, 2) x (1, 1, 1, 12)
# [(0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 2, 12),
#  (1, 1, 0, 12),
#  (1, 1, 1, 12),
#  (1, 1, 2, 12),
#  (2, 1, 0, 12),
#  (2, 1, 1, 12),
#  (2, 1, 2, 12)]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df1,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# Optimization terminated successfully.
#          Current function value: 5.206993
#          Iterations: 2
#          Function evaluations: 39
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:1897.3452848784736
# Optimization terminated successfully.
#          Current function value: 5.073307
#          Iterations: 3
#          Function evaluations: 84
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1850.6838889997905
# Optimization terminated successfully.
#          Current function value: 5.065289
#          Iterations: 2
#          Function evaluations: 67
# ARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:1849.7650434696834
# Optimization terminated successfully.
#          Current function value: 5.123938
#          Iterations: 2
#          Function evaluations: 46
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:1869.1133665705654
# Optimization terminated successfully.
#          Current function value: 5.062904
#          Iterations: 4
#          Function evaluations: 161
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:1848.8972122163564
# Optimization terminated successfully.
#          Current function value: 5.072983
#          Iterations: 2
#          Function evaluations: 98
# ARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:1854.5659595130405
# Optimization terminated successfully.
#          Current function value: 5.114813
#          Iterations: 1
#          Function evaluations: 34
# ARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:1867.7919120654728
# Optimization terminated successfully.
#          Current function value: 5.058865
#          Iterations: 7
#          Function evaluations: 342
# ARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:1849.426768928833
# Optimization terminated successfully.
#          Current function value: 5.056081
#          Iterations: 4
#          Function evaluations: 242
# ARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:1850.4135491092175
# Optimization terminated successfully.
#          Current function value: 5.051774
#          Iterations: 2
#          Function evaluations: 55
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:1842.8456736001294
# Optimization terminated successfully.
#          Current function value: 4.852127
#          Iterations: 3
#          Function evaluations: 172
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1772.1741778585813
# Optimization terminated successfully.
#          Current function value: 4.852070
#          Iterations: 3
#          Function evaluations: 152
# ARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:1774.1533139171527
# Optimization terminated successfully.
#          Current function value: 4.935251
#          Iterations: 2
#          Function evaluations: 94
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:1802.4313064108728
# Optimization terminated successfully.
#          Current function value: 4.852411
#          Iterations: 4
#          Function evaluations: 267
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1774.2777698100163
# Optimization terminated successfully.
#          Current function value: 4.852021
#          Iterations: 4
#          Function evaluations: 304
# ARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:1776.1356795258212
# Optimization terminated successfully.
#          Current function value: 4.892203
#          Iterations: 3
#          Function evaluations: 177
# ARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:1788.7618564887812
# Optimization terminated successfully.
#          Current function value: 4.851336
#          Iterations: 7
#          Function evaluations: 489
# ARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:1775.8861546600813
# Optimization terminated successfully.
#          Current function value: 4.851349
#          Iterations: 4
#          Function evaluations: 346
# ARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:1777.8910855335798
# Optimization terminated successfully.
#          Current function value: 5.050528
#          Iterations: 2
#          Function evaluations: 68
# ARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:1844.392128379602
# Optimization terminated successfully.
#          Current function value: 4.850371
#          Iterations: 3
#          Function evaluations: 155
# ARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:1773.5351337049392
# Optimization terminated successfully.
#          Current function value: 4.850394
#          Iterations: 3
#          Function evaluations: 183
# ARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:1775.5433618763554
# Optimization terminated successfully.
#          Current function value: 4.927799
#          Iterations: 3
#          Function evaluations: 162
# ARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:1801.7188317740695
# Optimization terminated successfully.
#          Current function value: 4.851177
#          Iterations: 4
#          Function evaluations: 306
# ARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:1775.8284878982804
# Optimization terminated successfully.
#          Current function value: 4.850258
#          Iterations: 4
#          Function evaluations: 290
# ARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:1777.4939851587224
# Optimization terminated successfully.
#          Current function value: 4.891431
#          Iterations: 3
#          Function evaluations: 235
# ARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:1790.4808800221213
# Optimization terminated successfully.
#          Current function value: 4.848903
#          Iterations: 9
#          Function evaluations: 701
# ARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:1777.0007496327012
# Optimization terminated successfully.
#          Current function value: 4.850303
#          Iterations: 4
#          Function evaluations: 332
# ARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:1779.5103833277453
# Optimization terminated successfully.
#          Current function value: 5.104399
#          Iterations: 2
#          Function evaluations: 51
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1862.0011250883424
# Optimization terminated successfully.
#          Current function value: 4.952917
#          Iterations: 3
#          Function evaluations: 119
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1808.86184492647
# Optimization terminated successfully.
#          Current function value: 4.950186
#          Iterations: 3
#          Function evaluations: 148
# ARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:1809.867761970213
# Optimization terminated successfully.
#          Current function value: 5.016931
#          Iterations: 2
#          Function evaluations: 70
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:1832.1630072104576
# Optimization terminated successfully.
#          Current function value: 4.950453
#          Iterations: 4
#          Function evaluations: 196
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1809.964854627336
# Optimization terminated successfully.
#          Current function value: 4.952275
#          Iterations: 3
#          Function evaluations: 188
# ARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:1812.6280959024523
# Optimization terminated successfully.
#          Current function value: 4.993570
#          Iterations: 2
#          Function evaluations: 96
# ARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:1825.659611325319
# Optimization terminated successfully.
#          Current function value: 4.948990
#          Iterations: 8
#          Function evaluations: 472
# ARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:1811.4322338330694
# Optimization terminated successfully.
#          Current function value: 4.949048
#          Iterations: 4
#          Function evaluations: 292
# ARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:1813.4534816997188
# Optimization terminated successfully.
#          Current function value: 5.032079
#          Iterations: 5
#          Function evaluations: 188
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1837.676635622141
# Optimization terminated successfully.
#          Current function value: 4.849944
#          Iterations: 4
#          Function evaluations: 200
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1773.3795748531813
# Optimization terminated successfully.
#          Current function value: 4.849944
#          Iterations: 5
#          Function evaluations: 298
# ARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:1775.3796526307888
# Optimization terminated successfully.
#          Current function value: 4.925794
#          Iterations: 4
#          Function evaluations: 199
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:1800.9890580793644
# Optimization terminated successfully.
#          Current function value: 4.849929
#          Iterations: 5
#          Function evaluations: 306
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1775.374153714954
# Optimization terminated successfully.
#          Current function value: 4.849833
#          Iterations: 4
#          Function evaluations: 297
# ARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:1777.339263958632
# Optimization terminated successfully.
#          Current function value: 4.891241
#          Iterations: 4
#          Function evaluations: 254
# ARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:1790.4116174892447
# Optimization terminated successfully.
#          Current function value: 4.848453
#          Iterations: 11
#          Function evaluations: 786
# ARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:1776.8370198354899
# Optimization terminated successfully.
#          Current function value: 4.849809
#          Iterations: 5
#          Function evaluations: 427
# ARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:1779.3306452536162
# Optimization terminated successfully.
#          Current function value: 5.045102
#          Iterations: 5
#          Function evaluations: 244
# ARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:1844.4173067046431
# Optimization terminated successfully.
#          Current function value: 4.850565
#          Iterations: 3
#          Function evaluations: 189
# ARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:1775.6056125759228
# Optimization terminated successfully.
#          Current function value: 4.850524
#          Iterations: 3
#          Function evaluations: 220
# ARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:1777.5907755213232
# Optimization terminated successfully.
#          Current function value: 4.926665
#          Iterations: 2
#          Function evaluations: 162
# ARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:1803.30600091347
# Optimization terminated successfully.
#          Current function value: 4.850713
#          Iterations: 5
#          Function evaluations: 434
# ARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:1777.659656639796
# Optimization terminated successfully.
#          Current function value: 4.850486
#          Iterations: 4
#          Function evaluations: 332
# ARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:1779.5767251382488
# Optimization terminated successfully.
#          Current function value: 4.891491
#          Iterations: 3
#          Function evaluations: 259
# ARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:1792.5026108495686
# Optimization terminated successfully.
#          Current function value: 4.846988
#          Iterations: 10
#          Function evaluations: 833
# ARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:1778.3036614534476
# Optimization terminated successfully.
#          Current function value: 4.850543
#          Iterations: 4
#          Function evaluations: 387
# ARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:1781.5975932996182
# Optimization terminated successfully.
#          Current function value: 5.087187
#          Iterations: 2
#          Function evaluations: 81
# ARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:1857.736239093239
# Optimization terminated successfully.
#          Current function value: 4.932573
#          Iterations: 3
#          Function evaluations: 152
# ARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:1803.4565605366768
# Optimization terminated successfully.
#          Current function value: 4.929467
#          Iterations: 3
#          Function evaluations: 185
# ARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:1804.3258637848244
# Optimization terminated successfully.
#          Current function value: 4.999303
#          Iterations: 2
#          Function evaluations: 92
# ARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:1827.7461521720488
# Optimization terminated successfully.
#          Current function value: 4.930563
#          Iterations: 4
#          Function evaluations: 239
# ARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:1804.724982338866
# Optimization terminated successfully.
#          Current function value: 4.931569
#          Iterations: 3
#          Function evaluations: 224
# ARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:1807.091242364147
# Optimization terminated successfully.
#          Current function value: 4.973234
#          Iterations: 2
#          Function evaluations: 118
# ARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:1820.257230331334
# Optimization terminated successfully.
#          Current function value: 4.927890
#          Iterations: 9
#          Function evaluations: 648
# ARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:1805.7520151915642
# Optimization terminated successfully.
#          Current function value: 4.928558
#          Iterations: 4
#          Function evaluations: 336
# ARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:1807.994949404437
# Optimization terminated successfully.
#          Current function value: 5.023499
#          Iterations: 2
#          Function evaluations: 146
# ARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:1836.5537478164028
# Optimization terminated successfully.
#          Current function value: 4.846017
#          Iterations: 3
#          Function evaluations: 242
# ARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:1773.9502646218014
# Optimization terminated successfully.
#          Current function value: 4.845987
#          Iterations: 3
#          Function evaluations: 223
# ARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:1775.939374299416
# Optimization terminated successfully.
#          Current function value: 4.920771
#          Iterations: 2
#          Function evaluations: 137
# ARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:1801.1606935095847
# Optimization terminated successfully.
#          Current function value: 4.846690
#          Iterations: 5
#          Function evaluations: 414
# ARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:1776.1950128484557
# Optimization terminated successfully.
#          Current function value: 4.845874
#          Iterations: 4
#          Function evaluations: 387
# ARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:1777.8982690696837
# Optimization terminated successfully.
#          Current function value: 4.886077
#          Iterations: 3
#          Function evaluations: 231
# ARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:1790.5320260822539
# Optimization terminated successfully.
#          Current function value: 4.845020
#          Iterations: 9
#          Function evaluations: 791
# ARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:1777.5874442724075
# Optimization terminated successfully.
#          Current function value: 4.846144
#          Iterations: 4
#          Function evaluations: 395
# ARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:1779.9965122406998
# Optimization terminated successfully.
#          Current function value: 5.023599
#          Iterations: 2
#          Function evaluations: 200
# ARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:1838.5899401936188
# Optimization terminated successfully.
#          Current function value: 4.846229
#          Iterations: 3
#          Function evaluations: 229
# ARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:1776.0272744635827
# Optimization terminated successfully.
#          Current function value: 4.846191
#          Iterations: 3
#          Function evaluations: 264
# ARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:1778.0134635353793
# Optimization terminated successfully.
#          Current function value: 4.921014
#          Iterations: 2
#          Function evaluations: 159
# ARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:1803.248926974005
# Optimization terminated successfully.
#          Current function value: 4.847012
#          Iterations: 4
#          Function evaluations: 393
# ARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:1778.3123639386213
# Optimization terminated successfully.
#          Current function value: 4.846016
#          Iterations: 4
#          Function evaluations: 439
# ARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:1779.94976294563
# Optimization terminated successfully.
#          Current function value: 4.886295
#          Iterations: 3
#          Function evaluations: 281
# ARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:1792.6113039935026
# Optimization terminated successfully.
#          Current function value: 4.839350
#          Iterations: 10
#          Function evaluations: 971
# ARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:1777.5232870530567
# Optimization terminated successfully.
#          Current function value: 4.846261
#          Iterations: 4
#          Function evaluations: 472
# ARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:1782.0389035181438

# %%
#ARIMA(0, 1, 1)x(2, 1, 0, 12)
mod = sm.tsa.statespace.SARIMAX(df1,
                                order=(2, 1, 2),
                                seasonal_order=(2, 1, 1, 12))
mod = mod.fit(method = 'powell')
print(mod.summary().tables[1])
# Out:
# Optimization terminated successfully.
#          Current function value: 4.839350
#          Iterations: 10
#          Function evaluations: 971
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7778      0.175     -4.447      0.000      -1.121      -0.435
# ar.L2          0.1526      0.089      1.712      0.087      -0.022       0.327
# ma.L1         -0.1170      0.250     -0.468      0.640      -0.607       0.373
# ma.L2         -0.8830      0.184     -4.797      0.000      -1.244      -0.522
# ar.S.L12       0.0098      0.140      0.070      0.944      -0.264       0.283
# ar.S.L24       0.0558      0.140      0.398      0.691      -0.219       0.331
# ma.S.L12      -0.9341      0.257     -3.628      0.000      -1.439      -0.429
# sigma2      1654.4026      0.000   8.54e+06      0.000    1654.402    1654.403
# ==============================================================================

# %%
mod.plot_diagnostics(figsize=(18, 8))
plt.show()

# %%
pred = mod.get_prediction(start=pd.to_datetime('2019-01-01'), dynamic=False)
# pred = mod.get_prediction(dynamic=False)

pred_ci = pred.conf_int()
ax = df1.plot(label='actual')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 4))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('water')
plt.legend()
plt.show()

# %% [markdown]
# ### To evaluate the model performance, we use Root Mean Squared Error (RMSE)

# %%
y_forecasted = pred.predicted_mean
y_truth = df1['2019-01-01':]
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error is {}'.format(round(mse, 2)))
print('The Root Mean Squared Error is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Mean Squared Error is 923.87
# The Root Mean Squared Error is 30.4

# %%
#Part IV: Forecasting
#Of course, Python can help us to forecast values even if you don't write the equation.

#If forecast one day ahead
#print(results.forecast(1))

#If forecast two days ahead
prediction = mod.forecast(10)
prediction
# Out:
# 2021-10-01    813.590438
# 2021-11-01    813.300020
# 2021-12-01    799.428888
# 2022-01-01    804.531165
# 2022-02-01    796.469907
# 2022-03-01    804.495271
# 2022-04-01    787.336174
# 2022-05-01    783.091434
# 2022-06-01    798.644038
# 2022-07-01    798.502221
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
import pickle

# %%
# Save the model under the cwd
pkl_filename = "sarima_original.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(mod, file)

# %%
# Load the saved model
with open("sarima_original.pkl", 'rb') as file:
   res = pickle.load(file)

# %%
# Now you can use the model
predicted_values = res.forecast(4)
predicted_values
# Out:
# 2021-10-01    813.590438
# 2021-11-01    813.300020
# 2021-12-01    799.428888
# 2022-01-01    804.531165
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
# model = mod.save('file')
# # fittedModel = model.fit(disp=0,method='css')

# %%
# from statsmodels.tsa.arima.model import ARIMAResults
# model = ARIMAResults.load('file')
# predicted_values = model.predict(n_periods=2)
# predicted_values

# %%
df1.tail()
# Out:
# Timestamp
# 2021-05-01    792.677419
# 2021-06-01    787.600000
# 2021-07-01    764.741935
# 2021-08-01    770.548387
# 2021-09-01    836.571429
# Freq: MS, Name: Water, dtype: float64

# %%
# # Forecast
# n_periods = 24
# fitted, confint = sxmodel.predict(n_periods=n_periods, 
#                                   exogenous=np.tile(seasonal_index.value, 2).reshape(-1,1), 
#                                   return_conf_int=True)

# index_of_fc = pd.date_range(data.index[-1], periods = n_periods, freq='MS')

# # make series for plotting purpose
# fitted_series = pd.Series(fitted, index=index_of_fc)
# lower_series = pd.Series(confint[:, 0], index=index_of_fc)
# upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# # Plot
# plt.plot(data['value'])
# plt.plot(fitted_series, color='darkgreen')
# plt.fill_between(lower_series.index, 
#                  lower_series, 
#                  upper_series, 
#                  color='k', alpha=.15)

# plt.title("SARIMAX Forecast of a10 - Drug Sales")
# plt.show()
